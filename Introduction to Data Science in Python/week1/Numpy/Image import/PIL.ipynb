# %%
from PIL import Image

# %%
from IPython.display import display

# %%
im= Image.open('mnk.jpg')

# %%
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1375x1375 at 0x23EA5800640>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import math

# %%
array=np.array(im)

# %%
print(array.shape)
# Out:
# (1375, 1375, 3)

# %%
array
# Out:
# array([[[133, 134, 136],
#         [132, 133, 135],
#         [136, 137, 139],
#         ...,
#         [171, 172, 174],
#         [167, 168, 170],
#         [160, 161, 163]],
#
#        [[135, 136, 138],
#         [134, 135, 137],
#         [138, 139, 141],
#         ...,
#         [167, 168, 170],
#         [165, 166, 168],
#         [162, 163, 165]],
#
#        [[136, 137, 139],
#         [134, 135, 137],
#         [139, 140, 142],
#         ...,
#         [162, 163, 165],
#         [162, 163, 165],
#         [165, 166, 168]],
#
#        ...,
#
#        [[102, 102, 100],
#         [ 90,  90,  88],
#         [ 73,  73,  71],
#         ...,
#         [ 88,  89,  91],
#         [ 88,  89,  91],
#         [ 86,  87,  89]],
#
#        [[129, 129, 127],
#         [120, 120, 118],
#         [103, 103, 101],
#         ...,
#         [ 88,  89,  91],
#         [ 88,  89,  91],
#         [ 87,  88,  90]],
#
#        [[121, 121, 119],
#         [126, 126, 124],
#         [125, 125, 123],
# ...

# %%
mask =np.full(array.shape,255)
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
mod_img=array-mask

# %%
mod_img=mod_img*-1

# %%
mod_img=mod_img.astype(np.uint8)

# %%
mod_img
# Out:
# array([[[122, 121, 119],
#         [123, 122, 120],
#         [119, 118, 116],
#         ...,
#         [ 84,  83,  81],
#         [ 88,  87,  85],
#         [ 95,  94,  92]],
#
#        [[120, 119, 117],
#         [121, 120, 118],
#         [117, 116, 114],
#         ...,
#         [ 88,  87,  85],
#         [ 90,  89,  87],
#         [ 93,  92,  90]],
#
#        [[119, 118, 116],
#         [121, 120, 118],
#         [116, 115, 113],
#         ...,
#         [ 93,  92,  90],
#         [ 93,  92,  90],
#         [ 90,  89,  87]],
#
#        ...,
#
#        [[153, 153, 155],
#         [165, 165, 167],
#         [182, 182, 184],
#         ...,
#         [167, 166, 164],
#         [167, 166, 164],
#         [169, 168, 166]],
#
#        [[126, 126, 128],
#         [135, 135, 137],
#         [152, 152, 154],
#         ...,
#         [167, 166, 164],
#         [167, 166, 164],
#         [168, 167, 165]],
#
#        [[134, 134, 136],
#         [129, 129, 131],
#         [130, 130, 132],
# ...

# %%
display(Image.fromarray(mod_img))
# Out:
# <PIL.Image.Image image mode=RGB size=1375x1375 at 0x23EA5EDCD60>

# %%
reshaped=np.reshape(mod_img,(255))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-95fbc859b52d> in <module>
# ----> 1 reshaped=np.reshape(mod_img,(255))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~\Desktop\project1\env\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# ~\Desktop\project1\env\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 5671875 into shape (255,)
